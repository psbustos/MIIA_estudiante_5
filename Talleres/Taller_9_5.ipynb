# %% [markdown]
# <img src="Archivos/miad4.png" width=800x>
#
# ## Interactividad usando `panel`
#
# En este taller podrás poner en práctica los conceptos aprendidos acerca del uso del paquete `panel`. Usarás `panel` con el fin de crear dashboards como herramienta de apoyo al momento de resolver problemas específicos en un contexto de Analytics.
#
# Instrucciones y condiciones generales: Esta es una actividad calificada y, por lo tanto, debe ser resuelta individualmente.
#
# ### Al desarrollar este taller podrás verificar tu progreso en:
#
# 1. Programar la funcionalidad de un dashboard en `panel`.
# 2. Agregar gráficos y widgets para hacer visualizaciones agradables en `panel`.
# 3. Personalizar dashobards para generar distintas visualizaciones interactivas en `panel`.

# %%
import panel as pn
import plotly.graph_objects as go
import pandas as pd
pn.extension('plotly')

# %% [markdown]
# ## Pregunta 1

# %% [markdown]
# Con la base de datos *COVID-19.csv* crea un dashboard en `panel` que:
#
# 1. Permita crear un diagrama de barras horizontal que muestre los casos de COVID-19 de acuerdo a la selección de los siguentes criterios:<br />
#     a. Casos o muertes.<br />
#     b. Periodo: Histórico, Últimos 7 días y Últimas 24 horas.<br />
#     Pista: utilice un control de tipo `RadioButtonGroup` para cada uno de los dos criterios.<br />
# 2. Contenga un diagrama de barras horizontal de las muertes por millón de personas.
# 3. Permita visualizar a tráves de un diagrama de barras horizontal los casos en cada una de las regiones de la Organización Munidal de la Salud.
#
# Nota: a excpeción de las regiones, muestre los 10 mayores valores en cada gráfico.

# %% [markdown]
# | <center>Variable</center> |<center>Descripción</center> |
# | :-- | :-- |
# | Name | País |
# | WHO Region | Región de la OMS |
# | Cases - cumulative total | Total de casos hasta el momento |
# | Cases - cumulative total per 1 million population | Número de casos acumulado por millón de personas |
# | Cases - newly reported in last 7 days | Número de casos nuevos en los últimos 7 días |
# | Cases - newly reported in last 24 hours | Número de casos nuevos en las últimas 24 horas |
# | Deaths - cumulative total | Total de muertes hasta el momento |
# | Deaths - cumulative total per 1 million population | Número de muertes acumulado por millón de personas |
# | Deaths - newly reported in last 7 days | Número de muertes nuevas en los últimos 7 días |
# | Deaths - newly reported in last 24 hours | Número de muertes nuevas en las últimas 24 horas |

# %%
# YOUR CODE HERE
df = pd.read_csv('Archivos/COVID-19.csv')
df.head(20)
#raise NotImplementedError()
# Out:
#                           Name             WHO Region  \
# 0     United States of America               Americas
# 1                        India        South-East Asia
# 2                       Brazil               Americas
# 3           Russian Federation                 Europe
# 4           The United Kingdom                 Europe
# 5                       France                 Europe
# 6                        Spain                 Europe
# 7                        Italy                 Europe
# 8                       Turkey                 Europe
# 9                      Germany                 Europe
# 10                    Colombia               Americas
# 11                   Argentina               Americas
# 12                      Mexico               Americas
# 13                      Poland                 Europe
# 14                South Africa                 Africa
# 15  Iran (Islamic Republic of)  Eastern Mediterranean
# 16                     Ukraine                 Europe
# 17                        Peru               Americas
# 18                   Indonesia        South-East Asia
# 19                     Czechia                 Europe
#
#     Cases - cumulative total  \
# 0                   26547977
# 1                   10826363
# 2                    9447165
# 3                    3967281
# 4                    3929839
# 5                    3262505
# 6                    2913425
# 7                    2625098
# 8                    2524786
# 9                    2284010
# 10                   2142660
# 11                   1970009
# 12                   1912871
# 13                   1550255
# 14                   1473700
# 15                   1459370
# 16                   1244849
# 17                   1173045
# 18                   1147010
# 19                   1034975
#
#     Cases - cumulative total per 1 million population  \
# 0                                            80204.73
# 1                                             7845.17
# 2                                            44444.82
# 3                                            27185.36
# 4                                            57888.79
# 5                                            49982.07
# 6                                            62312.88
# 7                                            43417.44
# 8                                            29936.14
# 9                                            27260.71
# 10                                           42109.64
# 11                                           43588.35
# 12                                           14836.19
# 13                                           40961.53
# 14                                           24847.96
# 15                                           17374.91
# 16                                           28464.26
# 17                                           35577.16
# 18                                            4193.46
# 19                                           96645.52
#
#     Cases - newly reported in last 7 days  \
# 0                                  871365
# 1                                   80180
# 2                                  328652
# 3                                  116842
# 4                                  133747
# 5                                  136154
# 6                                   82192
# 7                                   83315
# 8                                   53885
# 9                                   67647
# 10                                  65027
# 11                                  54647
# 12                                  70978
# 13                                  36870
# 14                                  24464
# 15                                  47639
# 16                                  25394
# 17                                  47170
# 18                                  80697
# 19                                  50201
#
#     Cases - newly reported in last 24 hours  Deaths - cumulative total  \
# 0                                    129961                     455735
# 1                                     12059                     154996
# 2                                     50872                     230034
# 3                                     16048                      76661
# 4                                     18262                     112092
# 5                                     20586                      78389
# 6                                         0                      60802
# 7                                     13439                      91003
# 8                                      7897                      26685
# 9                                      8616                      61517
# 10                                     7248                      55403
# 11                                     8374                      48985
# 12                                    13051                     164290
# 13                                     4725                      39087
# 14                                     3184                      46180
# 15                                     6983                      58412
# 16                                     3370                      23597
# 17                                     7993                      41933
# 18                                    12156                      31393
# 19                                     4863                      17235
#
#     Deaths - cumulative total per 1 million population  \
# 0                                             1376.83
# 1                                              112.32
# 2                                             1082.21
# 3                                              525.31
# 4                                             1651.18
# 5                                             1200.93
# 6                                             1300.44
# 7                                             1505.13
# 8                                              316.40
# 9                                              734.23
# 10                                            1088.83
# 11                                            1083.84
# 12                                            1274.23
# 13                                            1032.77
# 14                                             778.64
# 15                                             695.44
# 16                                             539.56
# 17                                            1271.78
# 18                                             114.77
# 19                                            1609.40
#
#     Deaths - newly reported in last 7 days  \
# 0                                    22562
# 1                                      722
# 2                                     7368
# 3                                     3479
# 4                                     6521
# 5                                     2923
# 6                                     1202
# 7                                     2724
# 8                                      820
# 9                                     4572
# 10                                    2119
# 11                                    1210
# 12                                    7711
# 13                                    1907
# 14                                    2229
# 15                                     523
# 16                                     890
# 17                                    1247
# 18                                    1665
# 19                                     927
#
#     Deaths - newly reported in last 24 hours Transmission Classification
# 0                                       3549      Community transmission
# 1                                         78           Clusters of cases
# 2                                       1239      Community transmission
# 3                                        432           Clusters of cases
# 4                                        828      Community transmission
# 5                                        191      Community transmission
# 6                                          0      Community transmission
# 7                                        385           Clusters of cases
# 8                                        108      Community transmission
# 9                                        231      Community transmission
# 10                                       272      Community transmission
# 11                                       285      Community transmission
# 12                                      1368      Community transmission
# 13                                        93      Community transmission
# 14                                       278      Community transmission
# 15                                        76      Community transmission
# 16                                        81      Community transmission
# 17                                       180      Community transmission
# 18                                       191      Community transmission
# 19                                       106      Community transmission

# %%
df3 =df.groupby(['WHO Region']).sum().sort_values(by=["Cases - cumulative total"], ascending=False)
df3
# Out:
#                        Cases - cumulative total  \
# WHO Region
# Americas                               46913216
# Europe                                 35481004
# South-East Asia                        13033797
# Eastern Mediterranean                   5828434
# Africa                                  2655316
# Western Pacific                         1481789
# Other                                       745
#
#                        Cases - cumulative total per 1 million population  \
# WHO Region
# Americas                                                      1158273.21
# Europe                                                        2721524.98
# South-East Asia                                                 62756.89
# Eastern Mediterranean                                          436199.32
# Africa                                                         217864.21
# Western Pacific                                                141908.60
# Other                                                               0.00
#
#                        Cases - newly reported in last 7 days  \
# WHO Region
# Americas                                             1568165
# Europe                                               1068726
# South-East Asia                                       177074
# Eastern Mediterranean                                 158494
# Africa                                                 84842
# Western Pacific                                        61765
# Other                                                      0
#
#                        Cases - newly reported in last 24 hours  \
# WHO Region
# Americas                                                237798
# Europe                                                  128578
# South-East Asia                                          25691
# Eastern Mediterranean                                    21456
# Africa                                                   10429
# Western Pacific                                           8380
# Other                                                        0
#
#                        Deaths - cumulative total  \
# WHO Region
# Americas                                 1092521
# Europe                                    780934
# South-East Asia                           200267
# Eastern Mediterranean                     136946
# Africa                                     65736
# Western Pacific                            25885
# Other                                         13
#
#                        Deaths - cumulative total per 1 million population  \
# WHO Region
# Americas                                                        20449.88
# Europe                                                          50141.52
# South-East Asia                                                   523.60
# Eastern Mediterranean                                            4999.50
# Africa                                                           3249.82
# Western Pacific                                                  1539.35
# Other                                                               0.00
#
#                        Deaths - newly reported in last 7 days  \
# WHO Region
# Americas                                                45350
# Europe                                                  32946
# South-East Asia                                          2560
# Eastern Mediterranean                                    2757
# Africa                                                   3232
# Western Pacific                                          1297
# Other                                                       0
#
#                        Deaths - newly reported in last 24 hours
# WHO Region
# Americas                                                   7332
# Europe                                                     3224
# South-East Asia                                             285
# Eastern Mediterranean                                       335
# Africa                                                      410
# Western Pacific                                             166
# Other                                                         0

# %%
# YOUR CODE HERE
titulo = '# Tablero de control Covid 19'
#raise NotImplementedError()

# %%
# YOUR CODE HERE
sel_1 = ["Casos", "Muertes"]
sel_2 = ["Histórico", "Últimos 7 días","Últimas 24 horas"]
seleccion1 = pn.widgets.Select(name='Casos o Muertes', options= sel_1)
seleccion2 = pn.widgets.Select(name='Periodicidad', options= sel_2)
#raise NotImplementedError()

# %%
# YOUR CODE HERE
@pn.depends(seleccion1.param.value, seleccion2.param.value)

def funcion_interactiva(seleccion1, seleccion2): 
    datos = df 
    
    columna = "Cases - cumulative total"
    if(seleccion1 == "Casos" and seleccion2 == "Histórico"):
        columna = "Cases - cumulative total"
    elif(seleccion1 == "Casos" and seleccion2 == "Últimos 7 días"):
        columna = "Cases - newly reported in last 7 days"
    elif(seleccion1 == "Casos" and seleccion2 == "Últimas 24 horas"):
        columna = "Cases - newly reported in last 24 hours"
    elif(seleccion1 == "Muertes" and seleccion2 == "Histórico"):
        columna = "Deaths - cumulative total"
    elif(seleccion1 == "Muertes" and seleccion2 == "Últimos 7 días"):
        columna = "Deaths - newly reported in last 7 days"
    elif(seleccion1 == "Muertes" and seleccion2 == "Últimas 24 horas"):
        columna = "Deaths - newly reported in last 24 hours"
    else:
        columna
        
    df1 = df.sort_values(by=[columna], ascending=False).head(10)    
    fig1 = go.Figure(go.Bar( x=df1['Name'],y=df1[columna]))
    fig1.update_layout( title= str(seleccion1) + " " + str(seleccion2))
    
    return fig1

def funcion2():
    datos = df
    df2 = df.sort_values(by=["Deaths - cumulative total per 1 million population"], ascending=False).head(10)
    fig2 = go.Figure(go.Bar( y=df2['Name'],x=df2["Deaths - cumulative total per 1 million population"],orientation='h'))
    fig2.update_layout( title= "Muertes por millón de personas")
    return fig2

def funcion3():
    datos = df
    df3 =df.groupby(['WHO Region']).sum().sort_values(by=["Cases - cumulative total"], ascending=False).reset_index()
    fig3 = go.Figure(go.Bar( y=df3["WHO Region"],x=df3["Cases - cumulative total"],orientation='h'))
    fig3.update_layout( title= "Total de Casos por Región de OMS")
    return fig3
#raise NotImplementedError()

# %%
# YOUR CODE HERE
tablero_control = pn.Column(pn.Row(pn.Column(titulo, seleccion1, seleccion2), funcion_interactiva),pn.Row(funcion2,funcion3))
#raise NotImplementedError()

# %%
# YOUR CODE HERE
tablero_control.servable()
#raise NotImplementedError()
# Out:
# Column
#     [0] Row
#         [0] Column
#             [0] Markdown(str)
#             [1] Select(name='Casos o Muertes', options=['Casos', 'Muertes'], value='Casos')
#             [2] Select(name='Periodicidad', options=['Histórico', ...], value='Histórico')
#         [1] ParamFunction(function)
#     [1] Row
#         [0] Column
#             [0] Column()
#             [1] Row
#                 [0] Plotly(Figure, name='interactive00114')
#         [1] Column
#             [0] Column()
#             [1] Row
#                 [0] Plotly(Figure, name='interactive00120')

# %%
# YOUR CODE HERE
tablero_control.show()
# Out:
# Launching server at http://localhost:60855
# WARNING:bokeh.core.validation.check:W-1002 (EMPTY_LAYOUT): Layout has no children: Column(id='1165', ...)
# WARNING:bokeh.core.validation.check:W-1002 (EMPTY_LAYOUT): Layout has no children: Column(id='1160', ...)

# %% [markdown]
# ## Créditos
#
# **Autor(es)**: Juan David Reyes Jaimes, Diego Alejandro Cely Gomez
#
# **Última actualización:** 26/08/2021
